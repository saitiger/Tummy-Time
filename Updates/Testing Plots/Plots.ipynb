# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from utils_plot import *

# %%
my_dict = data_dict_fill(data_dict2)

# %%
behaviour_plot_for_toy(df,'Popup',2,my_dict)
# Out:
#    Visit   Score       Score Name
# 0     V2  10.250             Look
# 1     V2  12.250   Simple Explore
# 2     V2   0.500  Complex Explore
# 3     V2   0.750         Function
# 4     V2   0.000         Solution
# 5     V3   2.250             Look
# 6     V3  16.875   Simple Explore
# 7     V3   5.250  Complex Explore
# 8     V3   5.250         Function
# 9     V3   0.000         Solution
# 10    V4   1.125             Look
# 11    V4   8.250   Simple Explore
# 12    V4  10.625  Complex Explore
# 13    V4   7.625         Function
# 14    V4   0.000         Solution

# %%
behaviour_count_greater_than_zero(df2, 'Gumball')
# Out:
# Number of Rows with value greater than zero
#         Metric Type Visit  Control  SPEEDI-EARLY  SPEEDI-LATE
# 0               TWS     2       20            17           21
# 1              Look     2       19            16           20
# 2    Simple Explore     2       18            11           17
# 3   Complex Explore     2        0             0            0
# 4          Function     2        0             0            0
# 5          Solution     2        0             0            0
# 6               TWS     3       16            11           22
# 7              Look     3       14             9           19
# 8    Simple Explore     3       16            11           22
# 9   Complex Explore     3        5             0            9
# 10         Function     3        1             0            4
# 11         Solution     3        0             0            0
# 12              TWS     4       17             9           21
# 13             Look     4       10             4           12
# 14   Simple Explore     4       17             9           21
# 15  Complex Explore     4       15             7           18
# 16         Function     4       15             8           16
# 17         Solution     4        1             0            0

# %%
behaviour_plot_combined(df2,'Complex Explore',3,my_dict)
# Out:
#   Visit      Score      Toy
# 0     2   0.000000  Gumball
# 1     3   1.105263  Gumball
# 2     4   6.736842  Gumball
# 3     2   0.000000     Cups
# 4     3   0.210526     Cups
# 5     4   3.684211     Cups
# 6     2   0.315789    Popup
# 7     3   6.000000    Popup
# 8     4  10.421053    Popup

# %%
toy_score_comparison(df2,'Gumball',2,'Cognitive Raw','Gross Motor Raw',my_dict)
# Out:
#   Visit      Score       Score Type
# 0     2  15.481573              TWS
# 1     3  24.843750              TWS
# 2     4  56.125000              TWS
# 3     2  12.375000    Cognitive Raw
# 4     3  30.125000    Cognitive Raw
# 5     4  43.000000    Cognitive Raw
# 6     2  12.250000  Gross Motor Raw
# 7     3  25.375000  Gross Motor Raw
# 8     4  42.125000  Gross Motor Raw

# %%
demographic_plots(df2, 'Sex', 'TWS',my_dict)
# Out:
#    C_1_SEX         TWS Visit     SEX
# 0      1.0  103.057143    V2  Female
# 1      2.0   99.407407    V2    Male
# 2      1.0  172.800000    V3  Female
# 3      2.0  152.296296    V3    Male
# 4      1.0  231.571429    V4  Female
# 5      2.0  246.962963    V4    Male

# %%
Bayley_vs_APSP_plot(df2,'GMs',3,my_dict)
# Out:
# C_2_APS_RPM    18.142857
# C_3_APS_RPM    35.166667
# C_4_APS_RPM    53.702381
# C_2_BS3_GMs     9.500000
# C_3_BS3_GMs     6.785714
# C_4_BS3_GMs     6.714286
# dtype: float64

# %%
create_toy_plot(df2,'Popup',my_dict)
# Out:
#   Treatment Group         V2         V3         V4
# 0         Control  24.821429  45.321429  64.678571
# 1    SPEEDI-Early  23.100840  52.125000  65.934949
# 2     SPEEDI-Late  22.078947  48.000000  64.872807

# %%
create_toy_plot_grp_wise(df,2,my_dict)
# Out:
#   Toy Type      Score Visit
# 0  Gumball  14.979924    V2
# 1  Gumball  25.849763    V3
# 2  Gumball  55.888889    V4
# 3     Cups  15.079133    V2
# 4     Cups  27.954545    V3
# 5     Cups  41.166103    V4
# 6    Popup  22.289284    V2
# 7    Popup  50.363636    V3
# 8    Popup  67.442177    V4

# %%
plot_aps_scores(df2,'RPM','stripplot',my_dict)

# %%
plot_bins(df, 'Visit 4')
